# %% [markdown]
# # Chest X-ray segmentation using openCV library

# %% [markdown]
# First we import the necessary libraries:

# %%
import sys
import os
import glob
import numpy as np
import cv2
import scipy.misc
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# Next, lets look at the data. The CXR (Chest X-ray) images we got from the JSRT (Japanese Society of Radiological Technology). There are 256 images in this free database. Here is an example:

# %%
input_dir = 'C:\\Users\\ilaiw\\Documents\\project\\JSRT_PNG\\'
basename = 'JPCLN001.png'
filename = input_dir + basename
img = cv2.imread(filename,0) 
print('Image shape is:', img.shape)
plt.imshow(img,cmap='gray')
plt.colorbar()
# Out:
# Image shape is: (512, 512)

# %% [markdown]
# And now we start the segmentation, following this first image as an example. Later on we shall see the total results of the 246 images.
#
# Our first step was to erase the spinal cord, which can be found by calculating the maximum when summing along the first axis:

# %%
def eraseMax(img,eraseLineCenter=0,eraseLineWidth=30,draw=False):
    sumpix0=np.sum(img,0)
    if draw:
        plt.plot(sumpix0)
        plt.title('Sum along axis=0')
        plt.xlabel('Column number')
        plt.ylabel('Sum of column')
    max_r2=np.int_(len(sumpix0)/3)+np.argmax(sumpix0[np.int_(len(sumpix0)/3):np.int_(len(sumpix0)*2/3)])
    cv2.line(img,(max_r2+eraseLineCenter,0),(max_r2+eraseLineCenter,512),0,eraseLineWidth)
    return img

img_erased = eraseMax(img,draw=True)

# %% [markdown]
# And we get 3 maxima, the largest for the spinal chord.
#
# after erasing we get:

# %%
plt.imshow(img_erased,cmap='gray')
plt.colorbar()

# %% [markdown]
# Next step was to naromalize the images, and to bring out more detail, using CLAHE:

# %%
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
img_clahe = clahe.apply(img_erased)   
plt.imshow(img_clahe,cmap='gray')

# %% [markdown]
# Next we applied openCV's Blackhat kernel:

# %%
ker = 169
kernel = np.ones((ker,ker),np.uint8)
blackhat = cv2.morphologyEx(img_clahe, cv2.MORPH_BLACKHAT, kernel)    
plt.imshow(blackhat,cmap='gray')

# %% [markdown]
# In the next step we applied a threshold:

# %%
threshold = 45
ret, thresh = cv2.threshold(blackhat, threshold, 255, 0)
plt.imshow(thresh,cmap='gray')

# %% [markdown]
# Next we used openCV's corner detection function on the original image, which was useful because the lungs have many small details which can be detected as corners:

# %%
def get_cmask(img, maxCorners=3800, qualityLevel=0.001, minDistance=1,Cradius=6):
    corners = cv2.goodFeaturesToTrack(img, maxCorners, qualityLevel, minDistance)
    corners = np.int0(corners)
    cmask = np.zeros(img.shape)
    for corner in corners:
        x,y = corner.ravel()
        cv2.circle(cmask,(x,y),Cradius,1,-1)
    return cmask

cmask = get_cmask(img_clahe)
plt.imshow(cmask,cmap='gray')

# %% [markdown]
# And so the corner mask gives us the lungs without the background.
#
# So in the next step we multiply the two previous results:

# %%
mask = np.multiply(cmask,thresh).astype('uint8')
plt.imshow(mask,cmap='gray')

# %% [markdown]
# Next we used a median blur to clean the mask:

# %%
median = cv2.medianBlur(mask,23) 
plt.imshow(median,cmap='gray')

# %% [markdown]
# Next we use openCV's contour finder to get only the 2 largest contours, which are the lungs:

# %%
def contourMask(image):
    im2,contours,hierc = cv2.findContours(image,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE) 
    area = np.zeros(len(contours))
    for j in range(len(contours)):
        cnt = contours[j]
        area[j] = cv2.contourArea(cnt)
    mask = np.zeros(image.shape)
    cv2.drawContours(mask, contours, np.argmax(area), (255), -1)#draw largest contour-usually right lung   
    temp = np.copy(area[np.argmax(area)])
    area[np.argmax(area)]=0
    if area[np.argmax(area)] > temp/10:#make sure 2nd largest contour is also lung, not 2 lungs connected
        cv2.drawContours(mask, contours, np.argmax(area), (255), -1)#draw second largest contour  
    contours.clear() 
    return mask

contour_mask = contourMask(median).astype('uint8')
plt.imshow(contour_mask,cmap='gray')

# %% [markdown]
# And so this is our result for the rough segmentation of the lungs. Now let us compare to the ground truth segmentation of the image, performed by expert radilogists and available on the image science institute https://www.isi.uu.nl/Research/Databases/SCR/
#
# First lets look at the ground truth mask of out image:

# %%
GTmask_dir = 'C:\\Users\\ilaiw\\Documents\\project\\ground truth masks\\joined\\' 
GTmask = cv2.imread(GTmask_dir+basename,0) 
plt.imshow(GTmask,cmap='gray')

# %% [markdown]
# Now we can compute the success of our segmentation with the Jaccard index, given as TP/(TP+FP+FN):

# %%
def Jaccard(mask,GTmask):
    TP = cv2.bitwise_and(mask, GTmask) #true positive
    F = cv2.bitwise_xor(mask, GTmask) #false positive and false negative
    return np.count_nonzero(TP)/(np.count_nonzero(F)+np.count_nonzero(TP))

def JaccardVisualization(mask,GTmask):
    #rescaling to get different shades of gray
    GTmask = (GTmask/5)*2
    mask = (mask/5)*3
    combined = mask + GTmask
    return combined

J = Jaccard(contour_mask,GTmask)
plt.imshow(JaccardVisualization(contour_mask,GTmask),cmap='gray')
print(f'Jaccard index is {J}')
# Out:
# Jaccard index is 0.7508664649278033

# %% [markdown]
# In the above image:
#
# White = TP
#
# Black = TN
#
# Dark gray = FN
#
# Light gray = FP
#
# Next we loop through all the images, performing the same segmentation and calculate the overall Jaccard index:

# %%
# %%time
def seg(filename, blackHatKernel=169,threshold=45,medianKernel=23,maxCorners=3800,Cradius=6,clipLimit=2.0,
        tileGridSize=(8,8),eraseLineCenter=0):
    img = cv2.imread(filename,0) 
    rows,cols = img.shape

    img = eraseMax(img,eraseLineCenter)

    clahe = cv2.createCLAHE(clipLimit=clipLimit, tileGridSize=tileGridSize)
    img = clahe.apply(img)    

    ker = blackHatKernel
    kernel = np.ones((ker,ker),np.uint8)
    blackhat = cv2.morphologyEx(img, cv2.MORPH_BLACKHAT, kernel) 

    ret, thresh = cv2.threshold(blackhat, threshold, 255, 0)

    cmask = get_cmask(img,maxCorners,Cradius=Cradius)

    mask = np.multiply(cmask,thresh).astype('uint8')

    median = cv2.medianBlur(mask,medianKernel) 

    contour_mask = contourMask(median)   

    return contour_mask.astype('uint8')

Jvec = []
for filename in glob.glob(os.path.join(input_dir, '*.png')):

    basename = os.path.basename(filename)

    GTmask = cv2.imread(GTmask_dir+basename,0) 

    mask = seg(filename)

    J = Jaccard(mask,GTmask)

    Jvec.append(J)

Javg = np.mean(Jvec)
print(f'Average Jaccard index over all 246 images is {Javg}')
# Out:
# Average Jaccard index over all 246 images is 0.7795903224772878
# Wall time: 17.9 s
